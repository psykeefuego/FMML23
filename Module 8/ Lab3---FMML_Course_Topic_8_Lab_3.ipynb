# %% [markdown]
# <a href="https://colab.research.google.com/github/psykeefuego/FMML23/blob/main/Module%208/%20Lab3---FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 07:42:19--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   176MB/s    in 0.4s
#
# 2024-03-31 07:42:19 (176 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6963   1708.02666v1  This is the Proceedings of the 2017 ICML Works...  stat
# 23912   1303.2751v1  This paper presents a Gaussian Mixture Model (...    cs
# 26457  1610.06671v1  It is critical and meaningful to make image cl...    cs
# 22748  1705.09199v3  Generative Adversarial Networks (GANs) have be...  stat
# 7765   1803.02108v1  The effectiveness of Convolutional Neural Netw...    cs
# ...             ...                                                ...   ...
# 23816   1406.6558v2  We propose a new architecture for difficult im...    cs
# 5650   1505.07008v1  This contribution summarizes the results on th...  stat
# 21549   1005.1593v2  We improve recently published results about re...  stat
# 2466   1612.00583v1  Autonomous systems can be used to search for s...  stat
# 9666   1603.00284v1  We focus on the robust principal component ana...  stat
#
#                                                    title  year  \
# 6963   Proceedings of the 2017 ICML Workshop on Human...  2017
# 23912  Gaussian Mixture Model for Handwritten Script ...  2013
# 26457  Multi-view metric learning for multi-instance ...  2016
# 22748  Non-parametric estimation of Jensen-Shannon Di...  2017
# 7765                                            HexaConv  2018
# ...                                                  ...   ...
# 23816  $ N^4 $-Fields: Neural Network Nearest Neighbo...  2014
# 5650   An Overview of the Asymptotic Performance of t...  2015
# 21549  Refinements of Universal Approximation Results...  2010
# 2466   Active Search for Sparse Signals with Region S...  2016
# 9666   Dual Smoothing and Level Set Techniques for Va...  2016
#
#                                                 keywords
# 6963   [proceedings, interpretability, australia, pro...
# 23912  [handwritten, devanagari, emphasizes, signific...
# 26457  [meaningful, classification, retrieval, recogn...
# 22748  [generative, adversarial, framework, generativ...
# 7765   [effectiveness, convolutional, translation, in...
# ...                                                  ...
# 23816  [architecture, difficult, processing, operatio...
# 5650   [contribution, summarizes, asymptotic, perform...
# 21549  [published, resources, restricted, boltzmann, ...
# 2466   [autonomous, intuitively, algorithms, efficien...
# 9666   [principal, component, formulations, smoothing...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6963     [proceedings, interpretability, australia, pro...
# 23912    [handwritten, devanagari, emphasizes, signific...
# 26457    [meaningful, classification, retrieval, recogn...
# 22748    [generative, adversarial, framework, generativ...
# 7765     [effectiveness, convolutional, translation, in...
#                                ...
# 14298    [stochastic, algorithms, generalization, prope...
# 28644    [hyperspectralmultispectral, information, appl...
# 1131     [generative, applications, including, generati...
# 21505    [dimensionality, reduction, classification, co...
# 7139     [important, considering, different, representa...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8836 words.
# Out of those 4633 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0b1bbc79-0c23-45a7-9b67-ca4825e92048" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b1bbc79-0c23-45a7-9b67-ca4825e92048")) {                    Plotly.newPlot(                        "0b1bbc79-0c23-45a7-9b67-ca4825e92048",                        [{"x":["australia","interpretability","proceedings","percentage","deviation","identification","handwritten","underlying","directional","horizontal","decomposing","experimentation","furthermore","exhaustive","different","significance","distributions","remaining","emphasizes","accuracies","respectively","devanagari","parameters","detection","comparisons","efficiently","influence","accurately","construct","condition","implemented","information","characterize","distances","alternate","instances","complementary","functions","classification","iteratively","probability","computing","precisely","relationships","consistency","meaningful","recognition","retrieval","accomplish","meanwhile","optimizes","evaluation","projection","performance","corresponds","dependent","numerical","experiments","extracted","technique","representation","iterations","optimization","demonstrates","incorporating","statistical","generator","smoothing","effectively","empirical","distribution","distinction","pathologies","providing","vanishing","practical","counterpart","gradients","adversarial","divergence","discriminator","estimates","framework","objective","difficult","estimation","modelling","generative","effectiveness","parametric","explanations","dimensional","densities","rotational","significantly","reflections","translation","convolutional","implementation","outperforming","conventional","necessary","hexagonal","invariances","parameter","multiples","optimized","increased","interpolation","admissible","implement","rotations","transformations","anisotropy","convolution","invariance","outperforms","increases","translations","convolutions","inference","processes","collection","analytically","conjugacy","multiresolution","observations","dependencies","efficient","magnetoencephalography","conditional","theoretic","markovian","techniques","recordings","marginalize","hierarchically","partition","likelihood","approaches","surprisingly","instantiations","polynomial","quadratic","assumption","investigation","minimization","lipschitz","contributions","additional","arbitrary","designing","previously","particular","algorithms","contribution","differentially","differential","systematic","completely","extensions","approximations","scalability","magnitude","background","considered","tolerance","advantages","geometrically","separation","satisfies","divergences","selection","tractable","applications","procedures","separability","reformulates","demonstrate","including","foreground","separable","factorization","emphasizing","motivating","consequences","repositories","predictors","thoroughly","currently","observation","determined","systematically","reliability","implementations","randomforest","heuristics","extensively","carefully","categorical"],"y":[3,12,6,13,18,95,20,129,21,8,10,13,171,23,783,18,125,29,4,19,84,3,258,366,35,168,56,59,90,51,99,681,61,21,6,99,40,219,497,41,181,129,25,79,76,55,381,109,10,21,11,261,48,914,33,66,74,571,103,243,370,19,344,62,52,171,33,13,124,159,202,6,1,87,10,135,13,31,104,27,16,73,555,144,137,186,48,122,222,38,16,177,9,5,247,9,121,351,122,33,105,79,2,5,150,2,45,42,19,6,66,9,52,2,42,27,240,53,24,9,231,111,67,11,0,6,71,55,389,0,95,57,6,394,8,0,14,28,68,460,25,6,66,27,63,36,80,6,52,124,85,52,90,298,578,77,6,29,42,33,35,26,25,55,67,123,7,95,4,29,27,3,161,38,446,38,11,0,569,236,24,13,34,6,4,19,3,11,13,55,62,48,16,26,33,0,47,46,29,10],"type":"bar"},{"x":["australia","interpretability","proceedings","p ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4633,), (4633, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>ContextLocNet</span> <span style=''>Context</span> <span style=''>Aware</span> <span style=''>Deep</span> <span style=''>Network</span> <span style=''>Models</span> <span style=''>for</span> <span style=''>Weakly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Supervised</span> <span style='background-color:rgba(0, 255, 0, 0.6388888888888888);'>Localization</span> <br/><br/><span style=''>We</span> <span style=''>aim</span> <span style=''>to</span> <span style=''>localize</span> <span style=''>objects</span> <span style=''>in</span> <span style=''>images</span> <span style=''>using</span> <span style=''>image</span> <span style=''>level</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>supervision</span> <span style=''>only</span> <span style=''>Previous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>mainly</span> <span style=''>focus</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.48091603053435117);'>discriminative</span> <span style=''>object</span> <span style=''>regions</span> <span style=''>and</span> <span style=''>often</span> <span style=''>fail</span> <span style=''>to</span> <span style=''>locate</span> <span style=''>precise</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.5897435897435899);'>boundaries</span> <span style=''>We</span> <span style=''>address</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introducing</span> <span style=''>two</span> <span style=''>types</span> <span style=''>of</span> <span style=''>context</span> <span style=''>aware</span> <span style=''>guidance</span> <span style=''>models</span> <span style=''>additive</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contrastive</span> <span style=''>models</span> <span style=''>that</span> <span style=''>leverage</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>surrounding</span> <span style=''>context</span> <span style=''>regions</span> <span style=''>to</span> <span style=''>improve</span> <span style='background-color:rgba(0, 255, 0, 0.6388888888888888);'>localization</span> <span style=''>The</span> <span style=''>additive</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>encourages</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3947368421052632);'>predicted</span> <span style=''>object</span> <span style=''>region</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supported</span> <span style=''>by</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>surrounding</span> <span style=''>context</span> <span style=''>region</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contrastive</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>encourages</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3947368421052632);'>predicted</span> <span style=''>object</span> <span style=''>region</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>outstanding</span> <span style=''>from</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>surrounding</span> <span style=''>context</span> <span style=''>region</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>benefits</span> <span style=''>from</span> <span style=''>the</span> <span style=''>recent</span> <span style=''>success</span> <span style=''>of</span> <span style='ba ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>One</span> <span style=''>vs</span> <span style=''>Each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximation</span> <span style=''>to</span> <span style=''>Softmax</span> <span style=''>for</span> <span style=''>Scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probabilities</span> <br/><br/><span style=''>The</span> <span style=''>softmax</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>categorical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>plays</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prominent</span> <span style=''>role</span> <span style=''>in</span> <span style=''>modern</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>with</span> <span style=''>numerous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>areas</span> <span style=''>such</span> <span style=''>as</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>neural</span> <span style=''>language</span> <span style=''>modeling</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recommendation</span> <span style=''>systems</span> <span style=''>However</span> <span style=''>softmax</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>is</span> <span style=''>very</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>for</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>because</span> <span style=''>of</span> <span style=''>the</span> <span style=''>high</span> <span style=''>cost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normalizing</span> <span style=''>constant</span> <span style=''>Here</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>to</span> <span style=''>softmax</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>which</span> <span style=''>takes</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>a</span> <span style=''>rigorous</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style=''>exact</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>This</span> <span style=''>bound</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>product</span> <span style=''>over</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>and</span> <span style=''>it</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rg ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>How</span> <span style=''>to</span> <span style=''>Beat</span> <span style=''>the</span> <span style=''>Adaptive</span> <span style=''>Multi</span> <span style=''>Armed</span> <span style=''>Bandit</span> <br/><br/><span style=''>The</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>is</span> <span style=''>a</span> <span style=''>concise</span> <span style=''>model</span> <span style=''>for</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>iterated</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>under</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>In</span> <span style=''>each</span> <span style=''>round</span> <span style=''>a</span> <span style=''>gambler</span> <span style=''>must</span> <span style=''>pull</span> <span style=''>one</span> <span style=''>of</span> <span style=''>K</span> <span style=''>arms</span> <span style=''>of</span> <span style=''>a</span> <span style=''>slot</span> <span style=''>machine</span> <span style=''>without</span> <span style=''>any</span> <span style=''>foreknowledge</span> <span style=''>of</span> <span style=''>their</span> <span style=''>payouts</span> <span style=''>except</span> <span style=''>that</span> <span style=''>they</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uniformly</span> <span style=''>bounded</span> <span style=''>A</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>is</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>the</span> <span style=''>gamblers</span> <span style=''>regret</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>the</span> <span style=''>gamblers</span> <span style=''>total</span> <span style=''>payout</span> <span style=''>minus</span> <span style=''>the</span> <span style=''>largest</span> <span style=''>payout</span> <span style=''>which</span> <span style=''>would</span> <span style=''>have</span> <span style=''>been</span> <span style=''>achieved</span> <span style=''>by</span> <span style=''>any</span> <span style=''>fixed</span> <span style=''>arm</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hindsight</span> <span style=''>Note</span> <span style=''>that</span> <span style=''>the</span> <span style=''>gambler</span> <span style=''>is</span> <span style=''>only</span> <span style=''>told</span> <span style=''>the</span> <span style=''>payout</span> <span style=''>for</span> <span style=''>the</span> <span style=''>arm</span> <span style=''>actually</span> <span style=''>chosen</span> <span style=''>not</span> <span style=''>for</span> <span style=''>the</span> <span style=''>unchosen</span> <span style=''>arms</span> <span style=''>Almost</span> <span style=''>all</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>on</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>assumed</span> <span style=''>the</span> <span style=''>payouts</span> <span style=''>to</span> <span style=''>be</span> <span style=''>non</span> <span style=''>adaptive</span> <span style=''>in</span> <span style=''>the</span> <span style=''>sense</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3277870216306156);'>distribution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>payout</span> <span style=''>of</span> <span style=''>arm</span> <span style=''>j</span> <span style=''>in</span> <span style=''>round</span> <span style=''>i</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>of</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Tutorial</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Autoencoders</span> <br/><br/><span style=''>In</span> <span style=''>just</span> <span style=''>three</span> <span style=''>years</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Autoencoders</span> <span style=''>(VAEs)</span> <span style=''>have</span> <span style=''>emerged</span> <span style=''>as</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style=''>popular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complicated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>VAEs</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appealing</span> <span style=''>because</span> <span style=''>they</span> <span style=''>are</span> <span style=''>built</span> <span style=''>on</span> <span style=''>top</span> <span style=''>of</span> <span style=''>standard</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximators</span> <span style=''>(neural</span> <span style=''>networks)</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style=''>trained</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>VAEs</span> <span style=''>have</span> <span style=''>already</span> <span style=''>shown</span> <span style=''>promise</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generating</span> <span style=''>many</span> <span style=''>kinds</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complicated</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>handwritten</span> <span style=''>digits</span> <span style=''>faces</span> <span style=''>house</span> <span style=''>numbers</span> <span style=''>CIFAR</span> <span style=''>images</span> <span style=''>physical</span> <span style=''>models</span> <span style=''>of</span> <span style=''>scenes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmentation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicting</span> <span style=''>the</span> <span style=''>future</span> <span style=''>from</span> <span style=''>static</span> <span style=''>images</span> <span style=''>This</span> <span style=''>tutorial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuitions</span> <span style=''>behind</span> <span style=''>VAEs</span> <span style=''>explains</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mathematics</span> <span style=''>behind</span> <span style=''>them</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describes</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>behavior</span> <span style=''>No</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>Bayesian</span> <span style=''>methods</span> <span style=''>is</ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13176638176638178)
# 	information (0.24252136752136752)
# 	architecture (0.08297720797720798)
# 	experimental (0.14031339031339032)
# 	processing (0.10363247863247864)
# 	segmentation (0.07621082621082621)
# 	detection (0.13034188034188035)
# 	convolutional (0.125)
# 	different (0.27884615384615385)
# 	recognition (0.13568376068376067)
#
# Some Statistics words are:
# 	theoretical (0.15060240963855423)
# 	stochastic (0.13152610441767068)
# 	variables (0.13755020080321284)
# 	statistical (0.16014056224899598)
# 	estimation (0.16616465863453816)
# 	algorithm (0.3910642570281124)
# 	inference (0.20582329317269077)
# 	distribution (0.2003012048192771)
# 	dimensional (0.1992971887550201)
# 	regression (0.18122489959839358)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c8555e7b-5163-4b99-90f0-8582a24aad91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8555e7b-5163-4b99-90f0-8582a24aad91")) {                    Plotly.newPlot(                        "c8555e7b-5163-4b99-90f0-8582a24aad91",                        [{"x":["australia","interpretability","proceedings","percentage","deviation","identification","handwritten","underlying","directional","horizontal","decomposing","experimentation","furthermore","exhaustive","different","significance","distributions","remaining","emphasizes","accuracies","respectively","devanagari","parameters","detection","comparisons","efficiently","influence","accurately","construct","condition","implemented","information","characterize","distances","alternate","instances","complementary","functions","classification","iteratively","probability","computing","precisely","relationships","consistency","meaningful","recognition","retrieval","accomplish","meanwhile","optimizes","evaluation","projection","performance","corresponds","dependent","numerical","experiments","extracted","technique","representation","iterations","optimization","demonstrates","incorporating","statistical","generator","smoothing","effectively","empirical","distribution","distinction","pathologies","providing","vanishing","practical","counterpart","gradients","adversarial","divergence","discriminator","estimates","framework","objective","difficult","estimation","modelling","generative","effectiveness","parametric","explanations","dimensional","densities","rotational","significantly","reflections","translation","convolutional","implementation","outperforming","conventional","necessary","hexagonal","invariances","parameter","multiples","optimized","increased","interpolation","admissible","implement","rotations","transformations","anisotropy","convolution","invariance","outperforms","increases","translations","convolutions","inference","processes","collection","analytically","conjugacy","multiresolution","observations","dependencies","efficient","magnetoencephalography","conditional","theoretic","markovian","techniques","recordings","marginalize","hierarchically","partition","likelihood","approaches","surprisingly","instantiations","polynomial","quadratic","assumption","investigation","minimization","lipschitz","contributions","additional","arbitrary","designing","previously","particular","algorithms","contribution","differentially","differential","systematic","completely","extensions","approximations","scalability","magnitude","background","considered","tolerance","advantages","geometrically","separation","satisfies","divergences","selection","tractable","applications","procedures","separability","reformulates","demonstrate","including","foreground","separable","factorization","emphasizing","motivating","consequences","repositories","predictors","thoroughly","currently","observation","determined","systematically","reliability","implementations","randomforest","heuristics","extensively","carefully","categorical","incidents","afterwards","seriously","development","discussed","transform","knowledge","indeterminacy","capability","distributional","transforms","capturing","neighbors","correspondence","component","characterization","coefficients","effective","application","aggregate","individual","methodology","important","classifying","potential","themselves","supervised","delineation","intraoperative","diagnosis","demonstrated","considerable","operational","implementing","algorithm","traditional","boundaries","limitation","eliminate","efficiency","automatic","determines","temperature","diagnostic","explained","uncertainty","independent","graphplan","developed","extracting","correctly","constructi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	conjugacy
# 	magnetoencephalography
# 	marginalize
# 	reformulates
# 	randomforest
# 	preselected
# 	subexponential
# 	semiparametric
# 	nonparanormal
# 	inequalities
# 	kontorovich
# 	exponents
# 	mcallester
# 	shrinking
# 	changepoint
# 	submanifold
# 	laplacians
# 	asymptotics
# 	homomorphic
# 	resurgence
# Some words which never appear in Statistics papers:
# 	devanagari
# 	reflections
# 	multiples
# 	admissible
# 	rotations
# 	anisotropy
# 	intraoperative
# 	graphplan
# 	assistance
# 	brazilian
# 	pipelined
# 	versioning
# 	obviously
# 	accepting
# 	accomplishing
# 	postdiction
# 	quantizes
# 	broadcasts
# 	geographic
# 	transmissions

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.056888698682481e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7441666666666666

# %% [markdown]
# ---
